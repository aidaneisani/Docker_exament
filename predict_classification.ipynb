# %%
import joblib
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

# Faire les prédictions
def make_predictions(model, X_validation):
    return model.predict(X_validation)

if __name__ == "__main__":
    # Charger le modèle et les données
    model = joblib.load('model.joblib')
    X_val, y_val = joblib.load('validation_data.joblib')

    # Prédire avec le modèle et évaluer
    y_pred = make_predictions(model, X_val)

    conf_matrix = confusion_matrix(y_val, y_pred)
    plt.figure(figsize=(8, 6))
    sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', xticklabels=True, yticklabels=True)

    plt.xlabel('Predicted Labels')
    plt.ylabel('True Labels')
    plt.title('Confusion Matrix')

    plt.show()

    print("Accuracy:", accuracy_score(y_val, y_pred))
    f1 = 
    print(f"F1-score (weighted): {f1_score(y_val, y_test_pred, average='weighted')}")
    print("\nClassification Report:\n", classification_report(y_val, y_pred))
# Out:
# Accuracy: 0.963963963963964
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.96      0.98      0.97       347
#            1       0.95      0.96      0.96       338
#            2       0.98      0.96      0.97       314
#
#     accuracy                           0.96       999
#    macro avg       0.96      0.96      0.96       999
# weighted avg       0.96      0.96      0.96       999
